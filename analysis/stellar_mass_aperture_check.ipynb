# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from scipy.optimize import curve_fit
import seaborn as sb
import h5py
from matplotlib.backends.backend_pdf import PdfPages

plt.style.use('seaborn-ticks')
plot_style = {'axes.axisbelow': True,
             'axes.edgecolor': '0',
             'axes.facecolor': 'white',
             'axes.grid': False,
             'axes.labelcolor': '.15',
             'axes.spines.bottom': True,
             'axes.spines.left': True,
             'axes.spines.right': True,
             'axes.spines.top': True,
             'figure.facecolor': 'white',
             'font.family': ['DejaVu Serif'],
             'font.serif': ['Times New Roman'],
             'grid.color': '.8',
             'grid.linestyle': '-',
             'image.cmap': 'rocket',
             'lines.solid_capstyle': 'round',
             'lines.linewidth': 2.5,
             'patch.edgecolor': 'w',
             'patch.force_edgecolor': True,
             'text.color': '.15',
             'xtick.bottom': True,
             'xtick.color': '.15',
             'xtick.direction': 'in',
             'xtick.top': True,
             'ytick.color': '.15',
             'ytick.direction': 'in',
             'ytick.left': True,
             'ytick.right': True}

linewidth = 2
axes_fontsize = 12
figsize = (5, 7.2)
dpi = 120

sb.set_style(plot_style)
palette = sb.color_palette('plasma', 4)

#palette = sb.color_palette('colorblind', 10)

# %%
data_directory = 'SPT2349_1e6_real01/'
data_file_fmt = '%s/snapshot_%s.hdf5'
snaps = range(1, 102)
radius = 30 / 2 # kpc

# %%
for snap in snaps:
    snap_str = str(snap).zfill(3)
    
    print('Snapshot #%s' % snap_str)
    data_file = data_file_fmt % (data_directory, snap_str)
    
    with h5py.File(data_file, 'r') as f:
        stellar_mass_1 = np.array(f['/PartType2/Masses']) * 1e10
        stellar_mass_2 = np.array(f['/PartType4/Masses']) * 1e10
        
        coords_1 = np.array(f['/PartType2/Coordinates'])
        coords_2 = np.array(f['/PartType4/Coordinates'])
    
    total_stellar_mass = np.sum(stellar_mass_1) + np.sum(stellar_mass_2)
    print('%g Msun' % total_stellar_mass)
    
    coords = np.vstack((coords_1, coords_2))
    radii = np.linalg.norm(coords, axis = 1)
    stellar_masses = np.concatenate((stellar_mass_1, stellar_mass_2))
    
    in_region = np.where(radii < radius)
    
    print('%g Msun' % np.sum(stellar_masses[in_region]))
    
    percentage = 100.0 * (np.sum(stellar_masses[in_region]) / total_stellar_mass)
    print('Percentage in region: %.1f' % percentage)
    print()
# Out:
# Snapshot #001
# 2.86228e+11 Msun
# 2.13779e+10 Msun
# Percentage in region: 7.5
#
# Snapshot #002
# 3.01233e+11 Msun
# 2.23062e+10 Msun
# Percentage in region: 7.4
#
# Snapshot #003
# 3.19955e+11 Msun
# 2.4937e+10 Msun
# Percentage in region: 7.8
#
# Snapshot #004
# 3.3997e+11 Msun
# 5.30904e+10 Msun
# Percentage in region: 15.6
#
# Snapshot #005
# 3.60913e+11 Msun
# 9.92674e+10 Msun
# Percentage in region: 27.5
#
# Snapshot #006
# 3.80946e+11 Msun
# 1.27048e+11 Msun
# Percentage in region: 33.4
#
# Snapshot #007
# 4.04708e+11 Msun
# 2.23142e+11 Msun
# Percentage in region: 55.1
#
# Snapshot #008
# 4.34104e+11 Msun
# 2.56948e+11 Msun
# Percentage in region: 59.2
#
# Snapshot #009
# 4.57645e+11 Msun
# 2.84207e+11 Msun
# Percentage in region: 62.1
#
# Snapshot #010
# 4.78642e+11 Msun
# 3.20441e+11 Msun
# Percentage in region: 66.9
#
# Snapshot #011
# 4.90755e+11 Msun
# 3.88924e+11 Msun
# Percentage in region: 79.3
#
# Snapshot #012
# 5.11342e+11 Msun
# 3.71305e+11 Msun
# Percentage in region: 72.6
#
# Snapshot #013
# 5.21521e+11 Msun
# 3.74352e+11 Msun
# Percentage in region: 71.8
#
# Snapshot #014
# 5.39511e+11 Msun
# 3.81321e+11 Msun
# Percentage in region: 70.7
#
# Snapshot #015
# 5.51708e+11 Msun
# 4.00225e+11 Msun
# Percentage in region: 72.5
#
# Snapshot #016
# 5.68596e+11 Msun
# 4.13021e+11 Msun
# Percentage in region: 72.6
#
# Snapshot #017
# 5.80557e+11 Msun
# 4.05171e+11 Msun
# Percentage in region: 69.8
#
# Snapshot #018
# 5.93086e+11 Msun
# 4.37282e+11 Msun
# Percentage in region: 73.7
#
# Snapshot #019
# 5.99401e+11 Msun
# 4.64372e+11 Msun
# Percentage in region: 77.5
#
# Snapshot #020
# 6.1401e+11 Msun
# 4.72455e+11 Msun
# Percentage in region: 76.9
#
# Snapshot #021
# 6.22272e+11 Msun
# 4.6188e+11 Msun
# Percentage in region: 74.2
#
# Snapshot #022
# 6.35092e+11 Msun
# 4.73919e+11 Msun
# Percentage in region: 74.6
#
# Snapshot #023
# 6.4128e+11 Msun
# 4.79495e+11 Msun
# Percentage in region: 74.8
#
# Snapshot #024
# 6.50383e+11 Msun
# 4.90023e+11 Msun
# Percentage in region: 75.3
#
# Snapshot #025
# 6.56206e+11 Msun
# 4.94741e+11 Msun
# Percentage in region: 75.4
#
# Snapshot #026
# 6.68e+11 Msun
# 5.30792e+11 Msun
# Percentage in region: 79.5
#
# Snapshot #027
# 6.73512e+11 Msun
# 5.2144e+11 Msun
# Percentage in region: 77.4
#
# Snapshot #028
# 6.84829e+11 Msun
# 5.16042e+11 Msun
# Percentage in region: 75.4
#
# Snapshot #029
# 6.8897e+11 Msun
# 5.23364e+11 Msun
# Percentage in region: 76.0
#
# Snapshot #030
# 6.93826e+11 Msun
# 5.3149e+11 Msun
# Percentage in region: 76.6
#
# Snapshot #031
# 6.93585e+11 Msun
# 5.35819e+11 Msun
# Percentage in region: 77.3
#
# Snapshot #032
# 7.02598e+11 Msun
# 5.53133e+11 Msun
# Percentage in region: 78.7
#
# Snapshot #033
# 7.07628e+11 Msun
# 5.68991e+11 Msun
# Percentage in region: 80.4
#
# Snapshot #034
# 7.17954e+11 Msun
# 5.72423e+11 Msun
# Percentage in region: 79.7
#
# Snapshot #035
# 7.19465e+11 Msun
# 5.70362e+11 Msun
# Percentage in region: 79.3
#
# Snapshot #036
# 7.25524e+11 Msun
# 5.77176e+11 Msun
# Percentage in region: 79.6
#
# Snapshot #037
# 7.27274e+11 Msun
# 5.74913e+11 Msun
# Percentage in region: 79.1
#
# Snapshot #038
# 7.32615e+11 Msun
# 5.82752e+11 Msun
# Percentage in region: 79.5
#
# Snapshot #039
# 7.33136e+11 Msun
# 5.94442e+11 Msun
# Percentage in region: 81.1
#
# Snapshot #040
# 7.37974e+11 Msun
# 5.95931e+11 Msun
# Percentage in region: 80.8
#
# Snapshot #041
# 7.42428e+11 Msun
# 6.0147e+11 Msun
# Percentage in region: 81.0
#
# Snapshot #042
# 7.48031e+11 Msun
# 6.09306e+11 Msun
# Percentage in region: 81.5
#
# Snapshot #043
# 7.46486e+11 Msun
# 6.04047e+11 Msun
# Percentage in region: 80.9
#
# Snapshot #044
# 7.51388e+11 Msun
# 6.05792e+11 Msun
# Percentage in region: 80.6
#
# Snapshot #045
# 7.54661e+11 Msun
# 6.11727e+11 Msun
# Percentage in region: 81.1
#
# Snapshot #046
# 7.60744e+11 Msun
# 6.24986e+11 Msun
# Percentage in region: 82.2
#
# Snapshot #047
# 7.64211e+11 Msun
# 6.24292e+11 Msun
# Percentage in region: 81.7
#
# Snapshot #048
# 7.62544e+11 Msun
# 6.20195e+11 Msun
# Percentage in region: 81.3
#
# Snapshot #049
# 7.66674e+11 Msun
# 6.19487e+11 Msun
# Percentage in region: 80.8
#
# Snapshot #050
# 7.6829e+11 Msun
# 6.17315e+11 Msun
# Percentage in region: 80.3
#
# Snapshot #051
# 7.71334e+11 Msun
# 6.26689e+11 Msun
# Percentage in region: 81.2
#
# Snapshot #052
# 7.71987e+11 Msun
# 6.40217e+11 Msun
# Percentage in region: 82.9
#
# Snapshot #053
# 7.7601e+11 Msun
# 6.42641e+11 Msun
# Percentage in region: 82.8
#
# Snapshot #054
# 7.76262e+11 Msun
# 6.30885e+11 Msun
# Percentage in region: 81.3
#
# Snapshot #055
# 7.78798e+11 Msun
# 6.33426e+11 Msun
# Percentage in region: 81.3
#
# Snapshot #056
# 7.7908e+11 Msun
# 6.339e+11 Msun
# Percentage in region: 81.4
#
# Snapshot #057
# 7.82682e+11 Msun
# 6.35375e+11 Msun
# Percentage in region: 81.2
#
# Snapshot #058
# 7.84875e+11 Msun
# 6.4107e+11 Msun
# Percentage in region: 81.7
#
# Snapshot #059
# 7.88363e+11 Msun
# 6.43359e+11 Msun
# Percentage in region: 81.6
#
# Snapshot #060
# 7.86957e+11 Msun
# 6.41287e+11 Msun
# Percentage in region: 81.5
#
# Snapshot #061
# 7.90139e+11 Msun
# 6.38811e+11 Msun
# Percentage in region: 80.8
#
# Snapshot #062
# 7.89949e+11 Msun
# 6.38098e+11 Msun
# Percentage in region: 80.8
#
# Snapshot #063
# 7.92375e+11 Msun
# 6.43536e+11 Msun
# Percentage in region: 81.2
#
# Snapshot #064
# 7.91186e+11 Msun
# 6.45662e+11 Msun
# Percentage in region: 81.6
#
# Snapshot #065
# 7.95208e+11 Msun
# 6.53289e+11 Msun
# Percentage in region: 82.2
#
# Snapshot #066
# 7.97502e+11 Msun
# 6.56178e+11 Msun
# Percentage in region: 82.3
#
# Snapshot #067
# 7.99702e+11 Msun
# 6.53784e+11 Msun
# Percentage in region: 81.8
#
# Snapshot #068
# 7.98658e+11 Msun
# 6.47902e+11 Msun
# Percentage in region: 81.1
#
# Snapshot #069
# 8.0018e+11 Msun
# 6.45114e+11 Msun
# Percentage in region: 80.6
#
# Snapshot #070
# 7.99831e+11 Msun
# 6.45906e+11 Msun
# Percentage in region: 80.8
#
# Snapshot #071
# 8.02062e+11 Msun
# 6.52722e+11 Msun
# Percentage in region: 81.4
#
# Snapshot #072
# 8.0031e+11 Msun
# 6.50863e+11 Msun
# Percentage in region: 81.3
#
# Snapshot #073
# 8.02357e+11 Msun
# 6.49672e+11 Msun
# Percentage in region: 81.0
#
# Snapshot #074
# 8.02813e+11 Msun
# 6.52708e+11 Msun
# Percentage in region: 81.3
#
# Snapshot #075
# 8.04004e+11 Msun
# 6.5631e+11 Msun
# Percentage in region: 81.6
#
# Snapshot #076
# 8.03436e+11 Msun
# 6.56584e+11 Msun
# Percentage in region: 81.7
#
# Snapshot #077
# 8.05014e+11 Msun
# 6.59638e+11 Msun
# Percentage in region: 81.9
#
# Snapshot #078
# 8.05869e+11 Msun
# 6.62299e+11 Msun
# Percentage in region: 82.2
#
# Snapshot #079
# 8.06878e+11 Msun
# 6.63726e+11 Msun
# Percentage in region: 82.3
#
# Snapshot #080
# 8.04254e+11 Msun
# 6.61587e+11 Msun
# Percentage in region: 82.3
#
# Snapshot #081
# 8.06205e+11 Msun
# 6.63477e+11 Msun
# Percentage in region: 82.3
#
# Snapshot #082
# 8.05394e+11 Msun
# 6.61965e+11 Msun
# Percentage in region: 82.2
#
# Snapshot #083
# 8.06468e+11 Msun
# 6.60651e+11 Msun
# Percentage in region: 81.9
#
# Snapshot #084
# 8.0618e+11 Msun
# 6.6182e+11 Msun
# Percentage in region: 82.1
#
# Snapshot #085
# 8.07074e+11 Msun
# 6.63142e+11 Msun
# Percentage in region: 82.2
#
# Snapshot #086
# 8.07586e+11 Msun
# 6.63613e+11 Msun
# Percentage in region: 82.2
#
# Snapshot #087
# 8.08485e+11 Msun
# 6.66032e+11 Msun
# Percentage in region: 82.4
#
# Snapshot #088
# 8.04716e+11 Msun
# 6.66183e+11 Msun
# Percentage in region: 82.8
#
# Snapshot #089
# 8.05487e+11 Msun
# 6.65185e+11 Msun
# Percentage in region: 82.6
#
# Snapshot #090
# 8.06039e+11 Msun
# 6.61479e+11 Msun
# Percentage in region: 82.1
#
# Snapshot #091
# 8.06714e+11 Msun
# 6.58913e+11 Msun
# Percentage in region: 81.7
#
# Snapshot #092
# 8.06404e+11 Msun
# 6.55287e+11 Msun
# Percentage in region: 81.3
#
# Snapshot #093
# 8.06947e+11 Msun
# 6.55275e+11 Msun
# Percentage in region: 81.2
#
# Snapshot #094
# 8.04613e+11 Msun
# 6.55251e+11 Msun
# Percentage in region: 81.4
#
# Snapshot #095
# 8.05122e+11 Msun
# 6.56433e+11 Msun
# Percentage in region: 81.5
#
# Snapshot #096
# 8.03345e+11 Msun
# 6.54113e+11 Msun
# Percentage in region: 81.4
#
# Snapshot #097
# 8.03822e+11 Msun
# 6.5459e+11 Msun
# Percentage in region: 81.4
#
# Snapshot #098
# 8.04016e+11 Msun
# 6.53625e+11 Msun
# Percentage in region: 81.3
#
# Snapshot #099
# 8.04478e+11 Msun
# 6.52469e+11 Msun
# Percentage in region: 81.1
#
# Snapshot #100
# 8.03689e+11 Msun
# 6.52269e+11 Msun
# Percentage in region: 81.2
#
# Snapshot #101
# 8.04111e+11 Msun
# 6.55313e+11 Msun
# Percentage in region: 81.5
